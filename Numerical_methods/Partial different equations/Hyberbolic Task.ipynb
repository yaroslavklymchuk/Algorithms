# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
results = pd.read_csv('/home/yaroslav/PycharmProjects/Algorithms/Numerical_methods/Partial different equations/results1.csv')

# %%
results
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>t</th>
#       <th>$$ ||u|| (t) $$</th>
#       <th>e(t)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.0</td>
#       <td>0.270000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.0</td>
#       <td>0.480000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0</td>
#       <td>0.630000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0</td>
# ...

# %%
results2 = pd.read_csv('/home/yaroslav/PycharmProjects/Algorithms/Numerical_methods/Partial different equations/results2.csv')

# %%
results2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>x</th>
#       <th>u(x)</th>
#       <th>e(x)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.1</td>
#       <td>0.011893</td>
#       <td>0.258107</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.2</td>
#       <td>-0.025643</td>
#       <td>0.505643</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.3</td>
#       <td>-0.044460</td>
#       <td>0.674460</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.4</td>
# ...
