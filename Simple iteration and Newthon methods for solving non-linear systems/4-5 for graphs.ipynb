# %%
import numpy as np
import matplotlib.pyplot as plt
import math


'''
cos(x + a) + by = c
x + sin(y + b) = d
'''
'''
sin(x+y) + cx = d
x^2 + y^2 = 1
'''

X = np.linspace(-10, 10, 100)
#Y = np.linspace(-10, 10, 100)
a = 0.966
b = -1.493
c = 0.651
d = 0.779

# %%
Y1 = (c - np.cos(X + a)) / b
Y2 = np.arcsin(d - X) - b

# %%
plt.plot(Y1)
plt.plot(Y2)
plt.show()
